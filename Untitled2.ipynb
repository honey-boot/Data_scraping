# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.31.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dharma raj\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dharma raj\anaconda3\lib\site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\dharma raj\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\dharma raj\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\dharma raj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\dharma raj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\dharma raj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\dharma raj\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dharma raj\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\dharma raj\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dharma raj\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.31.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.4 MB 3.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.4 MB 3.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.4 MB 4.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.4 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.4 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.4 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.4 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 4.0 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.31.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dharma raj\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dharma raj\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dharma raj\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dharma raj\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dharma raj\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dharma raj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# Collecting webdriver-managerNote: you may need to restart the kernel to use updated packages.
#
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\dharma raj\anaconda3\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\dharma raj\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\dharma raj\anaconda3\lib\site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->webdriver-manager) (2025.1.31)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2

# %%
pip install time
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement time (from versions: none)
# ERROR: No matching distribution found for time

# %%
import time

# %%
pip install ChromeDriverManager
# Out:
# Collecting ChromeDriverManager
#   Downloading chromedrivermanager-0.0.1-py3-none-any.whl.metadata (723 bytes)
# Requirement already satisfied: requests in c:\users\dharma raj\anaconda3\lib\site-packages (from ChromeDriverManager) (2.32.3)
# Collecting pypiwin32 (from ChromeDriverManager)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\dharma raj\anaconda3\lib\site-packages (from ChromeDriverManager) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->ChromeDriverManager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->ChromeDriverManager) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->ChromeDriverManager) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dharma raj\anaconda3\lib\site-packages (from requests->ChromeDriverManager) (2025.1.31)
# Downloading chromedrivermanager-0.0.1-py3-none-any.whl (1.4 kB)
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, ChromeDriverManager
# Successfully installed ChromeDriverManager-0.0.1 pypiwin32-223
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
#from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd


driver = webdriver.Chrome()

genres=["War","Fantasy","Western","News","Sports"]

for genre in genres:
    driver.get(f"https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres={genre}")

    time.sleep(5)

    def click_next_button():
        try:
             
            click_next = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
            ActionChains(driver).move_to_element(click_next).perform()
            click_next.click()
            time.sleep(5)
            return True
    
        except Exception:
            print("There are no content here to load",Exception)
            return False
    

    while click_next_button():
        print("Clicked next Button")

    print("There are no pages and Movies here")

    titles = []
    ratings = []
    votings = []
    durations = []

    movies_list = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

    for movies in movies_list:
        try:
            title = movies.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[1]/a/h3').text

            genre = movies.find_elements(By.XPATH,'//*[@id="genreAccordion"]/div[1]/label/span[1]/div').text

            rating = movies.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[1]').text

            voting = movies.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[2]').text

            duration = movies.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[2]/span[2]').text

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception:
            print("Error during occurring data extracting:{Exception}")
            continue

    df = pd.DataFrame({
        'Title': titles,
        'Rating': ratings,
        'Voting': votings,
        'Duration': durations,
        'Genre': genre
    })
    
    df.to_csv(f"{genre}_movies.csv", index=False)

    imdb_df = pd.DataFrame()
    imdb_df = pd.concat([imdb_df, df], ignore_index=True)

driver.quit()
imdb_df
# Out:
# Clicked next Button
# Clicked next Button
# There are no content here to load <class 'Exception'>
# There are no pages and Movies here
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# Clicked next Button
# There are no content here to load <class 'Exception'>
# There are no pages and Movies here
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Clicked next Button
# There are no content here to load <class 'Exception'>
# There are no pages and Movies here
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# There are no content here to load <class 'Exception'>
# There are no pages and Movies here
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# Error during occurring data extracting:{Exception}
# There are no content here to load <class 'Exception'>
# There are no pages and Movies here
# Empty DataFrame
# Columns: [Title, Rating, Voting, Duration, Genre]
# Index: []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd


driver = webdriver.Chrome()


genres = ["War","Fantasy","Western","News","Sport"]  

for genre in genres:
    url = f"https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres={genre}"
    driver.get(url)
    time.sleep(10)

    def click_load_more():
        try:
            load_more_button = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
            ActionChains(driver).move_to_element(load_more_button).perform()
            load_more_button.click()
            time.sleep(10)
            return True
        except Exception as e:
            print("No more content to load or error:", e)
            return False

    while click_load_more():
        print("Clicked 'Load More' button")

    print("✅ Finished loading all movies for", genre)

    titles = []
    ratings = []
    votings = []
    durations = []

    movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            print(f"Error extracting data for a movie: {e}")
            continue

    df = pd.DataFrame({
        'Title': titles,
        'Rating': ratings,
        'Votes': votings,
        'Duration': durations,
        'Genre': genre
    })
#imdb_df=pd.DataFrame()
    
df.to_csv(f"{genre}movies.csv",index=False)
imdb_df=pd.concat([imdb_df,df],ignore_index=True)
    
driver.quit()

df
# Out:
# Clicked 'Load More' button
# Clicked 'Load More' button
# No more content to load or error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF6834C2467]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# ✅ Finished loading all movies for War
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# ...
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#                                        Title Rating    Votes Duration  Genre
# 0                             1. Challengers    7.0   (154K)   2h 11m  Sport
# 1                       2. Queen of the Ring    6.9    (932)   2h 20m  Sport
# 2                 3. Young Woman and the Sea    7.5    (17K)    2h 9m  Sport
# 3                         4. Arthur the King    7.0    (34K)   1h 47m  Sport
# 4                             5. Under Paris    5.2    (36K)   1h 44m  Sport
# ..                                       ...    ...      ...      ...    ...
# 138  204. UFC 297: Strickland vs. du Plessis    6.4     (61)       3h  Sport
# 139                           205. Khapsyhyy    5.5      (7)   1h 30m  Sport
# 140      239. Is University Really Worth It?    5.2     (12)       1h  Sport
# 141                         244. Quote 10.35    8.0     (24)      35m  Sport
# 142           253. ¡Qué suerte hemos tenido!    7.5     (16)    1h 2m  Sport
#
# [143 rows x 5 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd

driver = webdriver.Chrome()

genres = ["War", "Fantasy", "Western", "News", "Sport","Music"]  
imdb_df = pd.DataFrame()  

for genre in genres:
    url = f"https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres={genre}"
    driver.get(url)
    time.sleep(10)

    def click_load_more():
        try:
            load_more_button = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
            ActionChains(driver).move_to_element(load_more_button).perform()
            load_more_button.click()
            time.sleep(10)
            return True
        except Exception as e:
            print("No more content to load or error:", e)
            return False

    while click_load_more():
        print("Clicked 'Load More' button")

    print("✅ Finished loading all movies for", genre)

    titles = []
    ratings = []
    votings = []
    durations = []

    movie_items = driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            print(f"Error extracting data for a movie: {e}")
            continue

    df = pd.DataFrame({
        'Title': titles,
        'Rating': ratings,
        'Votes': votings,
        'Duration': durations,
        'Genre': genre
    })

    
    df.to_csv(f"{genre}_movies.csv", index=False)

    
    imdb_df = pd.concat([imdb_df, df], ignore_index=True)

driver.quit()


imdb_df.to_csv("all_genres_movies.csv", index=False)


imdb_df.head()
# Out:
# Clicked 'Load More' button
# Clicked 'Load More' button
# No more content to load or error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF6834C2467]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# ✅ Finished loading all movies for War
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# ...
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#
# Error extracting data for a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF683665355+78597]
# 	GetHandleVerifier [0x00007FF6836653B0+78688]
# 	(No symbol) [0x00007FF6834191AA]
# 	(No symbol) [0x00007FF68346F149]
# 	(No symbol) [0x00007FF68346F3FC]
# 	(No symbol) [0x00007FF683461BEC]
# 	(No symbol) [0x00007FF68349712F]
# 	(No symbol) [0x00007FF683461AB6]
# 	(No symbol) [0x00007FF683497300]
# 	(No symbol) [0x00007FF6834BF2BB]
# 	(No symbol) [0x00007FF683496EC3]
# 	(No symbol) [0x00007FF6834603F8]
# 	(No symbol) [0x00007FF683461163]
# 	GetHandleVerifier [0x00007FF68390EF0D+2870973]
# 	GetHandleVerifier [0x00007FF6839096B8+2848360]
# 	GetHandleVerifier [0x00007FF683926993+2967875]
# 	GetHandleVerifier [0x00007FF68368019A+188746]
# 	GetHandleVerifier [0x00007FF68368847F+222255]
# 	GetHandleVerifier [0x00007FF68366D2D4+111236]
# 	GetHandleVerifier [0x00007FF68366D482+111666]
# 	GetHandleVerifier [0x00007FF6836535A9+5465]
# 	BaseThreadInitThunk [0x00007FFC27AF7374+20]
# 	RtlUserThreadStart [0x00007FFC283BCC91+33]
#                                       Title Rating    Votes Duration Genre
# 0  1. The Ministry of Ungentlemanly Warfare    6.8   (134K)    2h 2m   War
# 1                           2. William Tell    5.7   (2.4K)   2h 13m   War
# 2                   3. The Six Triple Eight    6.7    (26K)    2h 7m   War
# 3                     4. My Dead Friend Zoe    6.6   (2.2K)   1h 43m   War
# 4                           5. Dirty Angels    4.3   (3.4K)   1h 44m   War

# %%
Untitled2.ipynb
